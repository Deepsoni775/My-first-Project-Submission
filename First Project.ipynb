# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Deep Kumar Soni**
# I want to be a data scientist in future.

# %% [markdown]
# *I am intrested in data science because i want to learn new skills in software world as i am currently is sales field. I find data science quite intresting field as it has lot to learn and i believe in future data is going to be the biggest asset for any organization in order to be copetitive in market*

# %% [markdown]
# ### Addition of two numbers

# %%
print(5+5)
# Out:
# 10

# %% [markdown]
# # list of items
# ~~>I am making list of items that i have to buy from **Market**~~
#
# 1. vegetable
#
# ![alt text](https://www.cdc.gov/foodsafety/images/comms/features/GettyImages-1247930626-500px.jpg?_=00453)
#
# ---
# 2. milk
#
# ![alt text](https://post.healthline.com/wp-content/uploads/2019/11/milk-soy-hemp-almond-non-dairy-1200x628-facebook.jpg)
# ***
# 3. fruits
# ![alt text](https://www.healthyeating.org/images/default-source/home-0.0/nutrition-topics-2.0/general-nutrition-wellness/2-2-2-3foodgroups_fruits_detailfeature.jpg?sfvrsn=64942d53_4)
# ___
#
# **[You can Check Youtube as well](https://www.youtube.com/)**
